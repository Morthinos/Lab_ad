# %%
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %%
PATH_TO_TRAIN = '/train.csv'
PATH_TO_TEST = '/test.csv'

# %%
train = pd.read_csv(PATH_TO_TRAIN, index_col='PassengerId')
test = pd.read_csv(PATH_TO_TEST, index_col='PassengerId')

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
train.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
train.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
train[(train['Age'] == 14)]
# Out:
#              Survived  Pclass                                  Name     Sex  \
# PassengerId
# 10                  1       2   Nasser, Mrs. Nicholas (Adele Achem)  female
# 15                  0       3  Vestrom, Miss. Hulda Amanda Adolfina  female
# 40                  1       3           Nicola-Yarred, Miss. Jamila  female
# 436                 1       1             Carter, Miss. Lucile Polk  female
# 684                 0       3           Goodwin, Mr. Charles Edward    male
# 687                 0       3              Panula, Mr. Jaako Arnold    male
#
#               Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# PassengerId
# 10           14.0      1      0   237736   30.0708      NaN        C
# 15           14.0      0      0   350406    7.8542      NaN        S
# 40           14.0      1      0     2651   11.2417      NaN        C
# 436          14.0      1      2   113760  120.0000  B96 B98        S
# ...

# %%
train[(train['Sex'] == 'male') & (train['Embarked'] == 'S')]
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# 13                  0       3  Saundercock, Mr. William Henry  male  20.0
# ...               ...     ...                             ...   ...   ...
# 879                 0       3              Laleff, Mr. Kristo  male   NaN
# 882                 0       3              Markun, Mr. Johann  male  33.0
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 115.8+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # устанавливаем seaborn как по-умолчанию для отрисовки графиков

# %%
test = pd.read_csv('/test.csv')
train = pd.read_csv('/train.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train.shape #Общее количество записей и столбцов
# Out:
# (891, 12)

# %%
train.describe() #среднеквадратичное отклонение
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include=['O']) #статистики  для нечисловых данных
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# можно выделить что, 577 было мужчин, 644 чела отбыли из порта s
# один билет дублируется 7 раз и в одерй каюте могут жить до 4 чел

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum() #пропуски в записях возвраста каюты
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.shape
# Out:
# (418, 11)

# %%
test.shape
# Out:
# (418, 11)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test.isnull().sum() #пропуски в кабине и возраст
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
survived = train[train['Survived'] == 1]
not_survived = train[train['Survived'] == 0]

print ("Survived: %i (%.1f%%)"%(len(survived), (len(survived))/len(train)*100.0))
print ("Not Survived: %i (%.1f%%)"%(len(not_survived), (len(not_survived))/len(train)*100.0))
print ("Total: %i"%len(train))
#выщитываем процент выживания
# Out:
# Survived: 342 (38.4%)
# Not Survived: 549 (61.6%)
# Total: 891

# %%
train.Pclass.value_counts() #сколько кого в классе
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
train.groupby('Pclass').Survived.value_counts() #выжившие на классе
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
train[['Pclass', 'Survived']].groupby('Pclass', as_index = False).mean() # процент выжмвания
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
sns.barplot(x='Pclass', y='Survived', data=train, ci=None)
# Out:
# <ipython-input-19-6494f3412771>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', data=train, ci=None)
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
train.Sex.value_counts() #процент муж и жен
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train.groupby('Sex').Survived.value_counts() #выживание
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train.groupby('Sex').Survived.mean().plot(kind='bar')#график выж
# Out:
# <Axes: xlabel='Sex'>

# %%
tab = pd.crosstab(train['Pclass'], train['Sex'])
print (tab) #мж по классам
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
tab = pd.crosstab(train['Pclass'], train['Sex'])
print (tab)

tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.xlabel('Pclass')
plt.ylabel('Percentage')
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347
# Text(0, 0.5, 'Percentage')

# %%
sns.catplot(x='Pclass', y='Survived', hue='Sex', aspect=2, data=train, kind='point', ci=None)
# Out:
# <ipython-input-38-04faa1b69bf6>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x='Pclass', y='Survived', hue='Sex', aspect=2, data=train, kind='point', ci=None)

# %% [markdown]
# жен из 2 и 11 класса имеют +- 100 проц на выживание
# мен из 2 и 3 на 10 проц выж

# %%
tab = pd.crosstab(train['Embarked'], train['Pclass'])
print (tab) #класс отправление
# Out:
# Pclass      1    2    3
# Embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
tab.sum(0)
# Out:
# Pclass
# 1    214
# 2    184
# 3    491
# dtype: int64

# %%
tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.xlabel('Embarked')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
train.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train[['Embarked', 'Survived']].groupby(['Embarked']).mean()
train.groupby('Embarked').Survived.mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
train.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
train.groupby('Parch').Survived.value_counts()
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      1            65
#        0            53
# 2      0            40
#        1            40
# 3      1             3
#        0             2
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: Survived, dtype: int64

# %%
train[['Parch', 'Survived']].groupby(['Parch'], as_index=False).mean()
# Out:
#    Parch  Survived
# 0      0  0.343658
# 1      1  0.550847
# 2      2  0.500000
# 3      3  0.600000
# 4      4  0.000000
# 5      5  0.200000
# 6      6  0.000000

# %%
train.groupby('Parch').Survived.mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
train.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
train.groupby('SibSp').Survived.value_counts()
# Out:
# SibSp  Survived
# 0      0           398
#        1           210
# 1      1           112
#        0            97
# 2      0            15
#        1            13
# 3      0            12
#        1             4
# 4      0            15
#        1             3
# 5      0             5
# 8      0             7
# Name: Survived, dtype: int64

# %%
train[['SibSp', 'Survived']].groupby(['SibSp'], as_index=False).mean()

# %%
train.groupby('SibSp').Survived.mean().plot(kind='bar')

# %%
#возраст выж
fig = plt.figure(figsize=(12,4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)


sns.violinplot(x="Embarked", y="Age", hue="Survived", data=train, split=True, ax=ax1)
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=train, split=True, ax=ax2)
sns.violinplot(x="Sex", y="Age", hue="Survived", data=train, split=True, ax=ax3)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# 1 класс меньше детей и старше;молодых вживых больше
# дети 0-10 2 класса практически выжили
# большая часть детей выжили
# женщины от 20 до 40 имеют больший процент выж

# %%
total_survived = train[train['Survived']==1] #данные выж
total_not_survived = train[train['Survived']==0]# данные мертв
male_survived = train[(train['Survived']==1) & (train['Sex']=="male")]# муж выж
#male_survived = total_survived[total_survived['Sex']=='male']
female_survived = train[(train['Survived']==1) & (train['Sex']=="female")]#жен выж
male_not_survived = train[(train['Survived']==0) & (train['Sex']=="male")]#м дед
female_not_survived = train[(train['Survived']==0) & (train['Sex']=="female")]#ж дед

fig = plt.figure(figsize=[15,10])#создание графика
ax1 = fig.add_subplot(211)
sns.distplot(total_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue', ax = ax1)
sns.distplot(total_not_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red', axlabel='Age', ax = ax1)
#общее распределение воз выж не выж
ax2 = fig.add_subplot(223)
sns.distplot(female_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue', ax = ax2)
sns.distplot(female_not_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red', axlabel='Female Age', ax = ax2)
#женщины
ax3 = fig.add_subplot(224)
sns.distplot(male_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue', ax=ax3)
sns.distplot(male_not_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red', axlabel='Male Age', ax=ax3)
#муж
# Out:
# <ipython-input-38-c58f51b31d6b>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(total_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue', ax = ax1)
# <ipython-input-38-c58f51b31d6b>:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# таким образом можно понять что 0-5 дети имет больше шансов выжиить
# 18-40 и 80+ ж больше шансов выжить
# 0-14 муж имеют больший шанс

# %%
corr_matrix = train.corr()
corr_matrix
#температура выж
# Out:
# <ipython-input-39-310b2495afb6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = train.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(corr_matrix, vmax=0.6, square=True, annot=True)
# Out:
# <Axes: >

# %%
train_test_data = [train, test] # combining train and test dataset

for dataset in train_test_data:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.')#признак обращение

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# ...

# %%
pd.crosstab(train['Title'], train['Sex']) #распределение титулов и полов
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col', \
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4   Other  0.347826

# %%
title_mapping = {"Mr": 1, "Master": 2, "Mrs": 3, "Miss": 4, "Other": 5}
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(5)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      1
# 1      0          PC 17599  71.2833   C85        C      3
# 2      0  STON/O2. 3101282   7.9250   NaN        S      4
# 3      0            113803  53.1000  C123        S      3
# ...

# %%
sex_mapping = {'female': 0, 'male': 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)
    #конверт значения пол 0-ж 1-м

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      1
# 1          PC 17599  71.2833   C85        C      3
# 2  STON/O2. 3101282   7.9250   NaN        S      4
# 3            113803  53.1000  C123        S      3
# ...

# %%
train.Embarked.unique() #просмотр значения отправления
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
train.Embarked.value_counts() #кол-во пасс на каждой категории
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')
    #из-за того что s больше всего пасс то пустые значения заполняем s

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      1
# 1          PC 17599  71.2833   C85        C      3
# 2  STON/O2. 3101282   7.9250   NaN        S      4
# 3            113803  53.1000  C123        S      3
# ...

# %%
for dataset in train_test_data:
    #print(dataset.Embarked.unique())
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
    #распределяем значения в числовой вариант

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  Title
# 0         A/5 21171   7.2500   NaN         0      1
# 1          PC 17599  71.2833   C85         1      3
# 2  STON/O2. 3101282   7.9250   NaN         0      4
# 3            113803  53.1000  C123         0      3
# ...

# %%
#распределяем возраст по 5 разным группам в новом столбце и смотрим их выживаемость
for dataset in train_test_data:
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()

    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
    dataset['Age'][np.isnan(dataset['Age'])] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)

for dataset in train_test_data:
    dataset['AgeBand'] = pd.cut(train['Age'], 5)

print (train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean())
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.522936
# 1   (16.0, 32.0]  0.338462
# 2   (32.0, 48.0]  0.404858
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909
# <ipython-input-56-e456524ba17a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Age'][np.isnan(dataset['Age'])] = age_null_random_list

# %%
#распределяем возраст по группе
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0    2      1      0
# 2                             Heikkinen, Miss. Laina    0    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0    2      1      0
# 4                           Allen, Mr. William Henry    1    2      0      0
#
#              Ticket     Fare Cabin  Embarked  Title       AgeBand
# 0         A/5 21171   7.2500   NaN         0      1  (16.0, 32.0]
# 1          PC 17599  71.2833   C85         1      3  (32.0, 48.0]
# 2  STON/O2. 3101282   7.9250   NaN         0      4  (16.0, 32.0]
# ...

# %%
#в пустые значения заполняем срзнач значение платы за проезд и создаем 4 категории
for dataset in train_test_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())

for dataset in train_test_data:
    dataset['FareBand'] = pd.qcut(train['Fare'], 4)

print (train[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean())
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train.head()
#согласовываем между платой за проезд и группой
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0    2      1      0
# 2                             Heikkinen, Miss. Laina    0    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0    2      1      0
# 4                           Allen, Mr. William Henry    1    2      0      0
#
#              Ticket  Fare Cabin  Embarked  Title       AgeBand  \
# 0         A/5 21171     0   NaN         0      1  (16.0, 32.0]
# 1          PC 17599     3   C85         1      3  (32.0, 48.0]
# 2  STON/O2. 3101282     1   NaN         0      4  (16.0, 32.0]
# ...

# %%
#создаем новый признак размер семьи и
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['SibSp'] +  dataset['Parch'] + 1

print (train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean())

for dataset in train_test_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

print (train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean())
# Out:
#    FamilySize  Survived
# 0           1  0.303538
# 1           2  0.552795
# 2           3  0.578431
# 3           4  0.724138
# 4           5  0.200000
# 5           6  0.136364
# 6           7  0.333333
# 7           8  0.000000
# 8          11  0.000000
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %% [markdown]
# семьи от 2 до 4 имеет больше шансов на выживание.
# кто в одиночку меньше шансов на выживание.
# семьи  5+ меньше шансов на выживание

# %%
features_drop = ['Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'FareBand', 'AgeBand']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  FamilySize  IsAlone
# 0         0       3    1    1     0         0      1           2        0
# 1         1       1    0    2     3         1      3           2        0
# 2         1       3    0    1     1         0      4           1        1
# 3         1       1    0    2     3         0      3           2        0
# 4         0       3    1    2     1         0      1           1        1

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  FamilySize  IsAlone
# 0          892       3    1    2     0         2      1           1        1
# 1          893       3    0    2     0         0      3           2        0
# 2          894       2    1    3     1         2      1           1        1
# 3          895       3    1    1     1         0      1           1        1
# 4          896       3    0    1     1         0      3           3        0

# %%
#cоздаем матрицу темп выж (корреляция)
plt.figure(figsize=(15,6))
sns.heatmap(train.corr(), vmax=0.6, square=True, annot=True)
# Out:
# <Axes: >

# %%
X_train = train.drop('Survived', axis=1)#из трен набора
y_train = train['Survived']# ответ на ориг тр набор для X_train

X_test = test.drop("PassengerId", axis=1).copy()# новые записи

X_train.shape, y_train.shape, X_test.shape
# Out:
# ((891, 8), (891,), (418, 8))

# %%
from sklearn.linear_model import LogisticRegression #лог регрессия
from sklearn.svm import SVC, LinearSVC #вектора
from sklearn.neighbors import KNeighborsClassifier # ближ соседи
from sklearn.tree import DecisionTreeClassifier # класс деревья решений
from sklearn.ensemble import RandomForestClassifier # случайный лест
from sklearn.naive_bayes import GaussianNB #
from sklearn.linear_model import Perceptron #лин класс
from sklearn.linear_model import SGDClassifier #обуч лин класс

# %%
#лог регрессия
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred_log_reg = clf.predict(X_test)
acc_log_reg = round( clf.score(X_train, y_train) * 100, 2)
print (str(acc_log_reg) + ' percent')
# Out:
# 79.57 percent

# %%
#вектор
clf = SVC()
clf.fit(X_train, y_train)
y_pred_svc = clf.predict(X_test)
acc_svc = round(clf.score(X_train, y_train) * 100, 2)
print (acc_svc)
# Out:
# 83.5

# %%
#линейнное ядро
clf = LinearSVC()
clf.fit(X_train, y_train)
y_pred_linear_svc = clf.predict(X_test)
acc_linear_svc = round(clf.score(X_train, y_train) * 100, 2)
print (acc_linear_svc)
# Out:
# 80.13
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#ближайший сосед
clf = KNeighborsClassifier(n_neighbors = 3)
clf.fit(X_train, y_train)
y_pred_knn = clf.predict(X_test)
acc_knn = round(clf.score(X_train, y_train) * 100, 2)
print (acc_knn)
# Out:
# 85.97

# %%
#дерево решений
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred_decision_tree = clf.predict(X_test)
acc_decision_tree = round(clf.score(X_train, y_train) * 100, 2)
print (acc_decision_tree)
# Out:
# 89.11

# %%
#случайный лес
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred_random_forest = clf.predict(X_test)
acc_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print (acc_random_forest)
# Out:
# 89.11

# %%
#теорема байеса
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred_gnb = clf.predict(X_test)
acc_gnb = round(clf.score(X_train, y_train) * 100, 2)
print (acc_gnb)
# Out:
# 78.0

# %%
#Перцептрон
clf = Perceptron(max_iter=5, tol=None)
clf.fit(X_train, y_train)
y_pred_perceptron = clf.predict(X_test)
acc_perceptron = round(clf.score(X_train, y_train) * 100, 2)
print (acc_perceptron)
# Out:
# 69.36

# %%
#градиентный спуск
clf = SGDClassifier(max_iter=5, tol=None)
clf.fit(X_train, y_train)
y_pred_sgd = clf.predict(X_test)
acc_sgd = round(clf.score(X_train, y_train) * 100, 2)
print (acc_sgd)
# Out:
# 73.85

# %%
from sklearn.metrics import confusion_matrix
import itertools

clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train) #cоздаем случайный лес с 100 оценков и даем на обучение данные
y_pred_random_forest_training_set = clf.predict(X_train)
acc_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print ("Accuracy: %i %% \n"%acc_random_forest)

class_names = ['Survived', 'Not Survived']

# вычисояем матрицу ошибок
cnf_matrix = confusion_matrix(y_train, y_pred_random_forest_training_set)

cnf_matrix_percent = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#нормализация ошибок к 1 для выч процента

true_class_names = ['True Survived', 'True Not Survived']
predicted_class_names = ['Predicted Survived', 'Predicted Not Survived']
#создание табличной формы

df_cnf_matrix = pd.DataFrame(cnf_matrix,
                             index = true_class_names,
                             columns = predicted_class_names)

df_cnf_matrix_percent = pd.DataFrame(cnf_matrix_percent,
                                     index = true_class_names,
                                     columns = predicted_class_names)

plt.figure(figsize = (15,5))

plt.subplot(121)
sns.heatmap(df_cnf_matrix, annot=True, fmt='d')

plt.subplot(122)
sns.heatmap(df_cnf_matrix_percent, annot=True)
#пострени матрицы
# Out:
# Accuracy: 89 %
# <Axes: >

# %%
# импорт библиотек
from sklearn.datasets import load_titanic
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from graphviz import Source

# Load the dataset
iris = load_titanic()
X_test = titanic.data[:, 2:] # petal length and width
y_test = titanic.target

# DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(criterion='entropy',
                                  max_depth=2)
tree_clf.fit(X_test, y_test)

# Plot the decision tree graph
export_graphviz(
    tree_clf,
    out_file="iris_tree.dot",
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
 )

with open("titanic_tree.dot") as f:
    dot_graph = f.read()

Source(dot_graph)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-87-184abc87eda9> in <cell line: 2>()
#       1 # импорт библиотек
# ----> 2 from sklearn.datasets import load_titanic
#       3 from sklearn.tree import DecisionTreeClassifier
#       4 from sklearn.tree import export_graphviz
#       5 from graphviz import Source
#
# ImportError: cannot import name 'load_titanic' from 'sklearn.datasets' (/usr/local/lib/python3.10/dist-packages/sklearn/datasets/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
import re
import xgboost as xgb
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from IPython.display import Image as PImage
from subprocess import check_call
from PIL import Image, ImageDraw, ImageFont

train = pd.read_csv('/train.csv')
test = pd.read_csv('/test.csv')

PassengerId = test['PassengerId']

train.head(3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
original_train = train.copy() # клонируем данные
full_data = [train, test]

# смотрим наличие кауют
train['Has_Cabin'] = train["Cabin"].apply(lambda x: 0 if type(x) == float else 1)
test['Has_Cabin'] = test["Cabin"].apply(lambda x: 0 if type(x) == float else 1)
#размер семьи
for dataset in full_data:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
#семьи
for dataset in full_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
# заменяем на s
for dataset in full_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')
# ставим среднее на проезд
for dataset in full_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())

# заменяем нулевой возраст
for dataset in full_data:
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)

    dataset.loc[np.isnan(dataset['Age']), 'Age'] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)

# обращения
def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    # If the title exists, extract and return it.
    if title_search:
        return title_search.group(1)
    return ""

for dataset in full_data:
    dataset['Title'] = dataset['Name'].apply(get_title)
# группи руем титулы
for dataset in full_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

for dataset in full_data:
    # перевод в численность мж
    dataset['Sex'] = dataset['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

    # перевод титулов в числа
    title_mapping = {"Mr": 1, "Master": 2, "Mrs": 3, "Miss": 4, "Rare": 5}
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

    # перевод отправления в числа
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

    # перевод в числа тариф
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] 						        = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] 							        = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

    # перевод в числа возрастные группы
    dataset.loc[ dataset['Age'] <= 16, 'Age'] 					       = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] ;

# %%
# удаляем ненужные таблицы
drop_elements = ['PassengerId', 'Name', 'Ticket', 'Cabin', 'SibSp']
train = train.drop(drop_elements, axis = 1)
test  = test.drop(drop_elements, axis = 1)

# %%
train.head(3)
# Out:
#    Survived  Pclass  Sex  Age  Parch  Fare  Embarked  Has_Cabin  FamilySize  \
# 0         0       3    1    1      0     0         0          0           2
# 1         1       1    0    2      0     3         1          1           2
# 2         1       3    0    1      0     1         0          0           1
#
#    IsAlone  Title
# 0        0      1
# 1        0      3
# 2        1      4

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('корреляция', y=1.05, size=15)
sns.heatmap(train.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <Axes: title={'center': 'корреляция'}>

# %%
train[['Title', 'Survived']].groupby(['Title'], as_index=False).agg(['mean', 'count', 'sum'])
# Out:
#        Survived
#            mean count  sum
# Title
# 1      0.156673   517   81
# 2      0.575000    40   23
# 3      0.793651   126  100
# 4      0.702703   185  130
# 5      0.347826    23    8

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).agg(['mean', 'count', 'sum'])
# Out:
#      Survived
#          mean count  sum
# Sex
# 0    0.742038   314  233
# 1    0.188908   577  109

# %%
title_and_sex = original_train.copy()[['Name', 'Sex']]

# загаловок титул
title_and_sex['Title'] = title_and_sex['Name'].apply(get_title)

# пол
title_and_sex['Sex'] = title_and_sex['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

# распределения титула по полу
title_and_sex[['Title', 'Sex']].groupby(['Title'], as_index=False).agg(['mean', 'count', 'sum'])
# Out:
#                Sex
#               mean count  sum
# Title
# Capt      1.000000     1    1
# Col       1.000000     2    2
# Countess  0.000000     1    0
# Don       1.000000     1    1
# Dr        0.857143     7    6
# Jonkheer  1.000000     1    1
# Lady      0.000000     1    0
# Major     1.000000     2    2
# Master    1.000000    40   40
# Miss      0.000000   182    0
# Mlle      0.000000     2    0
# Mme       0.000000     1    0
# Mr        1.000000   517  517
# Mrs       0.000000   125    0
# Ms        0.000000     1    0
# Rev       1.000000     6    6
# Sir       1.000000     1    1

# %%
def get_gini_impurity(survived_count, total_count):
    survival_prob = survived_count/total_count
    not_survival_prob = (1 - survival_prob)
    random_observation_survived_prob = survival_prob
    random_observation_not_survived_prob = (1 - random_observation_survived_prob)
    mislabelling_survided_prob = not_survival_prob * random_observation_survived_prob
    mislabelling_not_survided_prob = survival_prob * random_observation_not_survived_prob
    gini_impurity = mislabelling_survided_prob + mislabelling_not_survided_prob
    return gini_impurity

# %%
# исход узлы
gini_impurity_starting_node = get_gini_impurity(342, 891)
gini_impurity_starting_node

# %%
gini_impurity_men = get_gini_impurity(109, 577)
gini_impurity_men
# Out:
# 0.3064437162277843

# %%
gini_impurity_women = get_gini_impurity(233, 314)
gini_impurity_women
# Out:
# 0.3828350034484158

# %%
men_weight = 577/891
women_weight = 314/891
weighted_gini_impurity_sex_split = (gini_impurity_men * men_weight) + (gini_impurity_women * women_weight)

sex_gini_decrease = weighted_gini_impurity_sex_split - gini_impurity_starting_node
sex_gini_decrease
# Out:
# -0.13964795747285214

# %%
gini_impurity_title_1 = get_gini_impurity(81, 517)
gini_impurity_title_1
# Out:
# 0.26425329886377663

# %%
gini_impurity_title_others = get_gini_impurity(261, 374)
gini_impurity_title_others
# Out:
# 0.42170207898424317

# %%
title_1_weight = 517/891
title_others_weight = 374/891
weighted_gini_impurity_title_split = (gini_impurity_title_1 * title_1_weight) + (gini_impurity_title_others * title_others_weight)

title_gini_decrease = weighted_gini_impurity_title_split - gini_impurity_starting_node
title_gini_decrease
# Out:
# -0.14267004758907514

# %%
cv = KFold(n_splits=10)            # кол-во ветвей
accuracies = list()
max_attributes = len(list(test))
depth_range = range(1, max_attributes + 1)

# проверка глубины от 1 до макс
# подробное инф
for depth in depth_range:
    fold_accuracy = []
    tree_model = tree.DecisionTreeClassifier(max_depth = depth)
    for train_fold, valid_fold in cv.split(train):
        f_train = train.loc[train_fold] # извлечение данных
        f_valid = train.loc[valid_fold] # извлечение данных

        model = tree_model.fit(X = f_train.drop(['Survived'], axis=1),
                               y = f_train["Survived"]) # согласование
        valid_acc = model.score(X = f_valid.drop(['Survived'], axis=1),
                                y = f_valid["Survived"])# согласование
        fold_accuracy.append(valid_acc)

    avg = sum(fold_accuracy)/len(fold_accuracy)
    accuracies.append(avg)


# отображение результатов
df = pd.DataFrame({"Max Depth": depth_range, "Average Accuracy": accuracies})
df = df[["Max Depth", "Average Accuracy"]]
print(df.to_string(index=False))
# Out:
#  Max Depth  Average Accuracy
#          1          0.782285
#          2          0.799189
#          3          0.828277
#          4          0.819288
#          5          0.814844
#          6          0.813758
#          7          0.812597
#          8          0.812597
#          9          0.817091
#         10          0.811473

# %%
y_train = train['Survived']
x_train = train.drop(['Survived'], axis=1).values
x_test = test.values


decision_tree = tree.DecisionTreeClassifier(max_depth = 3)
decision_tree.fit(x_train, y_train)

# прогноз рез
y_pred = decision_tree.predict(x_test)
submission = pd.DataFrame({
        "PassengerId": PassengerId,
        "Survived": y_pred
    })
submission.to_csv('submission.csv', index=False)

# экспорт данных
with open("tree1.dot", 'w') as f:
     f = tree.export_graphviz(decision_tree,
                              out_file=f,
                              max_depth = 3,
                              impurity = True,
                              feature_names = list(train.drop(['Survived'], axis=1)),
                              class_names = ['Died', 'Survived'],
                              rounded = True,
                              filled= True )

#Convert .dot to .png to allow display in web notebook
check_call(['dot','-Tpng','tree1.dot','-o','tree1.png'])

# Annotating chart with PIL
img = Image.open("tree1.png")
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf', 26)
draw.text((10, 0), # рисуем
          '"Титул <= 1,5" соответствует титулу "Мистер".',
          (0,0,255), # цвет
          font=font)
img.save('sample-out.png')
PImage("sample-out.png")
